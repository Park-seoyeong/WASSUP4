# %% [markdown]
# ### 정적 웹페이지(Static-Request)

# %% [markdown]
# ### 네이버증권 뉴스제목과 URL 수집하기
# https://finance.naver.com/

# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH = "https://finance.naver.com/"
resp = requests.get(PATH)

# %%
# 정상응답 확인하기
resp
# Out:
# <Response [200]>

# %%
resp?
# Out:
# Type:        Response
# String form: <Response [200]>
# File:        c:\users\82107\anaconda3\lib\site-packages\requests\models.py
# Docstring:
# The :class:`Response <Response>` object, which contains a
# server's response to an HTTP request.

# %%
requests.get?
# Out:
# Signature: requests.get(url, params=None, **kwargs)
# Docstring:
# Sends a GET request.
#
# :param url: URL for the new :class:`Request` object.
# :param params: (optional) Dictionary, list of tuples or bytes to send
#     in the query string for the :class:`Request`.
# :param \*\*kwargs: Optional arguments that ``request`` takes.
# :return: :class:`Response <Response>` object
# :rtype: requests.Response
# File:      c:\users\82107\anaconda3\lib\site-packages\requests\api.py
# Type:      function

# %%
resp.text
# Out:
# '\n\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t<title>네이버페이 증권</title>\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n\t\t<meta property="og:title" content="네이버페이 증권"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버페이 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20240904001252/css/finance_header.css\'>\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/css/finance.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/css/newstock3.css">\n\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/js/release/common.js"></script>\n\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240904001252/js/nhn.autocomplete.stock.js"></script>\n\t\n\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\t<!-- smart channel 광고 -->\n\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">\n\t\t</script>\n\t<script type="text/javascript">\n\t\t(function(){\n\t\t\tif (ieVersion === -1 || ieVersion > 10) {\n\t\t\t\twindow.gladsdk = window.gladsdk || { cmd: [] };\n\n\t\t\t\tgladsdk.cmd.push(function() {\n\t\t\t\t\t\tgladsdk.defineAdSlot({\n\t\t\t\t\t\t\tadUnitId: "p_new_stock",\n\t\t\t\t\t\t\tadSlotElementId: "_SmartChannelTopBanner",\n\t\t\t\t\t\t\tuct: "KR",\n\t\t\t\t\t\t\tcustomParam: {\n\t\t\t\t\t\t\t\tcalp: \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t"home"\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t});\n\n\n\n\t\t\t\t\t\tgladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {\n\t\t\t\t\t\t\t//console.log(gladsdk.event.AD_LOADED);\n\t\t\t\t\t\t});\n\t\t\t\t\t\tgladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {\n\t\t\t\t\t\t\t//console.log(gladsdk.event.AD_CLICKED);\n\t\t\t\t\t\t});\n\t\t\t\t\t\tgladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {\n\t\t\t\t\t\t\t//console.log(gladsdk.event.AD_IMPRESSED);\n\t\t\t\t\t\t});\n\t\t\t\t\t\tgladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {\n\t\t\t\t\t\t\t//TODO: 오류 로깅처리\n\t\t\t\t\t\t\t//console.log(gladsdk.event.ERROR);\n\t\t\t\t\t\t});\n\t\t\t\t\t});\n\t\t\t}\n\t\t})();\n\t</script>\n\t\n\n\t<link rel="shortcut icon" href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n\t\tdocument.write ...

# %%
html_src = resp.text

# %%
soup = BeautifulSoup(html_src, 'lxml')

# %% [markdown]
# 양이 많아서 text 찾기 힘드니까 dom객체 사용하는 것

# %% [markdown]
# ## quiz 주요뉴스의 목록을 추출해보자

# %%
# 주요뉴스 목록 찾기
taglist = soup.select('.section_strategy li a')
taglist
# Out:
# [<a href="/news/news_read.naver?mode=mainnews&amp;office_id=629&amp;article_id=0000323922" onclick="clickcr(this, 'tdn.list', '629_0000323922', '0', event);">알멩이 빠진 고려아연 기자회견, MBK·영풍과 분쟁 향방 자충수?</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=003&amp;article_id=0012802442" onclick="clickcr(this, 'tdn.list', '003_0012802442', '1', event);">中 금리 인하…한국 증시 영향은</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=016&amp;article_id=0002366446" onclick="clickcr(this, 'tdn.list', '016_0002366446', '2', event);">밸류업 지수 30일 도입…세제혜택이 성패 주요 변수</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=016&amp;article_id=0002366444" onclick="clickcr(this, 'tdn.list', '016_0002366444', '3', event);">日도 못 피한 수급난...K-밸류업 ETF 생존할까</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=016&amp;article_id=0002366403" onclick="clickcr(this, 'tdn.list', '016_0002366403', '4', event);">연기금 ‘밸류업 자금’으로 돌아온다면?…‘이곳’이 다시 뜬다 [투자360]</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=016&amp;article_id=0002366398" onclick="clickcr(this, 'tdn.list', '016_0002366398', '5', event);">“밸류업 지수 발표 수혜? 기대감 낮았던 ‘빈집’에 주목” [투자360]</a>]

# %%
# 항목 더블체크하기 # 관계 명확하게 지칭해주기
len(taglist)
# Out:
# 6

# %%
# 첫번째 뉴스 제목 추출
taglist[0].txt

# %%
taglist[0]['href']
# Out:
# '/news/news_read.naver?mode=mainnews&office_id=629&article_id=0000323922'

# %%
url = taglist[0]['href']
PATH+url

# 돌아가지만 강제로 합친거라 위험함 브라우저 편의기능때문에 접속 가능한것
# Out:
# 'https://finance.naver.com//news/news_read.naver?mode=mainnews&office_id=629&article_id=0000323922'

# %%
from urllib.parse import urljoin
urljoin(PATH, url)
# Out:
# 'https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=629&article_id=0000323922'

# %% [markdown]
# ## quiz: 네이버 증권 주요뉴스의 제목과 url 모두를 추출하여라

# %%
# 슬라이싱 필요
taglist['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 taglist['href']
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in taglist:
    url = PATH[:-1] + i['href']
    print(url)
# Out:
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=629&article_id=0000323922
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=003&article_id=0012802442
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=016&article_id=0002366446
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=016&article_id=0002366444
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=016&article_id=0002366403
# https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=016&article_id=0002366398

# %%
for i in taglist:
    title =  i.text
    print(title)
# Out:
# 알멩이 빠진 고려아연 기자회견, MBK·영풍과 분쟁 향방 자충수?
# 中 금리 인하…한국 증시 영향은
# 밸류업 지수 30일 도입…세제혜택이 성패 주요 변수
# 日도 못 피한 수급난...K-밸류업 ETF 생존할까
# 연기금 ‘밸류업 자금’으로 돌아온다면?…‘이곳’이 다시 뜬다 [투자360]
# “밸류업 지수 발표 수혜? 기대감 낮았던 ‘빈집’에 주목” [투자360]
